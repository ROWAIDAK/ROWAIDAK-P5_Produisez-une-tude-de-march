# %% [markdown]
# # Produisez une étude de marché

# %% [markdown]
# # Scénario
# Votre entreprise **d'agroalimentaire** souhaite se développer à l'international. Elle est spécialisée dans...
#  le poulet !
#
# L'international, oui, mais pour l'instant, le champ des possibles est bien large : aucun pays particulier ni aucun continent n'est pour le moment choisi. Tous les pays sont envisageables !
#
# Votre objectif sera d'aider **à cibler plus particulièrement certains pays**, dans le but d'approfondir ensuite l'étude de marché. Plus particulièrement, l'idéal serait de produire des "groupes" de pays, plus ou moins gros, dont on connaît les caractéristiques.
#
# Dans un premier temps, la stratégie est plutôt d'exporter les produits plutôt que de produire sur place, c'est-à-dire dans le(s) nouveau(x) pays ciblé(s).

# %% [markdown]
# Pour identifier les pays propices à une insertion dans le marché du poulet,
#  Il vous a été demandé de cibler les pays.
#  Etudier les régimes alimentaires de chaque pays, notamment en termes de protéines d'origine animale et en termes de calories.
#
#
# Construisez votre échantillon contenant l'ensemble des pays disponibles, chacun caractérisé par ces variables :
#
# différence de population entre une année antérieure (au choix) et l'année courante, exprimée en pourcentage ;
# proportion de protéines d'origine animale par rapport à la quantité totale de protéines dans la disponibilité alimentaire du pays ;
# disponibilité alimentaire en protéines par habitant ;
# disponibilité alimentaire en calories par habitant.
#
# Construisez un dendrogramme contenant l'ensemble des pays étudiés, puis coupez-le afin d'obtenir 5 groupes.
#
# Caractérisez chacun de ces groupes selon les variables cités précédemment, et facultativement selon d'autres variables que vous jugerez pertinentes (ex : le PIB par habitant). Vous pouvez le faire en calculant la position des centroïdes de chacun des groupes, puis en les commentant et en les critiquant au vu de vos objectifs.
#
# Donnez une courte liste de pays à cibler, en présentant leurs caractéristiques. Un découpage plus précis qu'en 5 groupes peut si besoin être effectué pour cibler un nombre raisonnable de pays.
#
# Visualisez vos  partitions dans le premier plan factoriel obtenu par ACP.
#
# Dans votre partition, vous avez obtenu des groupes distincts. Vérifiez donc qu'ils diffèrent réellement. Pour cela, réalisez les tests statistiques suivants :
#
# un test d'adéquation : parmi les 4 variables, ou parmi d'autres variables que vous trouverez pertinentes, trouvez une variable dont la loi est normale ;
# un test de comparaison de deux populations (dans le cas gaussien) : choisissez 2 clusters parmi ceux que vous aurez déterminé. Sur ces 2 clusters, testez la variable gaussienne grâce à un test de comparaison.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib as plt

# %%
#Versions utilisées
print("Jupyter Notebook : " + str(pd.__version__))
print("Pandas : " + str(pd.__version__))
print("Numpy : " + str(np.__version__))
print("Seaborn : " + str(sns.__version__))
# Out:
# Jupyter Notebook : 1.2.4
# Pandas : 1.2.4
# Numpy : 1.20.1
# Seaborn : 0.11.1

# %% [markdown]
# # 1. Import et traitement de la population par pays

# %%
df_population = pd.read_csv('datas/fao-populations_2019- 2013.csv' , header=0, sep=",", decimal=".")
df_population.head()
# Out:
#   Code Domaine                      Domaine  Code zone            Zone  \
# 0          FBS  Bilans Alimentaires (2010-)          2     Afghanistan
# 1          FBS  Bilans Alimentaires (2010-)          2     Afghanistan
# 2          FBS  Bilans Alimentaires (2010-)        202  Afrique du Sud
# 3          FBS  Bilans Alimentaires (2010-)        202  Afrique du Sud
# 4          FBS  Bilans Alimentaires (2010-)          3         Albanie
#
#    Code Élément            Élément  Code Produit     Produit  Code année  \
# 0           511  Population totale          2501  Population        2013
# 1           511  Population totale          2501  Population        2019
# 2           511  Population totale          2501  Population        2013
# 3           511  Population totale          2501  Population        2019
# 4           511  Population totale          2501  Population        2013
#
#    Année           Unité  Valeur Symbole Description du Symbole
# 0   2013  1000 personnes   32270       *   Chiffre non officiel
# 1   2019  1000 personnes   38042       *   Chiffre non officiel
# 2   2013  1000 personnes   53687       *   Chiffre non officiel
# 3   2019  1000 personnes   58558       *   Chiffre non officiel
# 4   2013  1000 personnes    2904       *   Chiffre non officiel

# %%
df_population.describe(include = 'all')
# Out:
#        Code Domaine                      Domaine   Code zone       Zone  \
# count           357                          357  357.000000        357
# unique            1                            1         NaN        179
# top             FBS  Bilans Alimentaires (2010-)         NaN  Argentine
# freq            357                          357         NaN          2
# mean            NaN                          NaN  128.389356        NaN
# std             NaN                          NaN   74.624470        NaN
# min             NaN                          NaN    1.000000        NaN
# 25%             NaN                          NaN   67.000000        NaN
# 50%             NaN                          NaN  123.000000        NaN
# 75%             NaN                          NaN  191.000000        NaN
# max             NaN                          NaN  351.000000        NaN
#
#         Code Élément            Élément  Code Produit     Produit  \
# count          357.0                357         357.0         357
# unique           NaN                  1           NaN           1
# top              NaN  Population totale           NaN  Population
# freq             NaN                357           NaN         357
# mean           511.0                NaN        2501.0         NaN
# std              0.0                NaN           0.0         NaN
# min            511.0                NaN        2501.0         NaN
# 25%            511.0                NaN        2501.0         NaN
# 50%            511.0                NaN        2501.0         NaN
# 75%            511.0                NaN        2501.0         NaN
# max            511.0                NaN        2501.0         NaN
#
#          Code année        Année           Unité        Valeur Symbole  \
# count    357.000000   357.000000             357  3.570000e+02     357
# unique          NaN          NaN               1           NaN       2
# top             NaN          NaN  1000 personnes           NaN       *
# freq            NaN          NaN             357           NaN     355
# mean    2016.008403  2016.008403             NaN  4.950347e+04     NaN
# std        3.004199     3.004199             NaN  1.821550e+05     NaN
# min     2013.000000  2013.000000             NaN  5.000000e+01     NaN
# 25%     2013.000000  2013.000000             NaN  2.859000e+03     NaN
# 50%     2019.000000  2019.000000             NaN  9.685000e+03     NaN
# 75%     2019.000000  2019.000000             NaN  2.978100e+04     NaN
# max     2019.000000  2019.000000             NaN  1.465634e+06     NaN
#
#        Description du Symbole
# count                     357
# unique                      2
# top      Chiffre non officiel
# freq                      355
# mean                      NaN
# std                       NaN
# min                       NaN
# 25%                       NaN
# 50%                       NaN
# 75%                       NaN
# max                       NaN

# %%
df_population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Code Domaine            357 non-null    object
#  1   Domaine                 357 non-null    object
#  2   Code zone               357 non-null    int64
#  3   Zone                    357 non-null    object
#  4   Code Élément            357 non-null    int64
#  5   Élément                 357 non-null    object
#  6   Code Produit            357 non-null    int64
#  7   Produit                 357 non-null    object
#  8   Code année              357 non-null    int64
#  9   Année                   357 non-null    int64
#  10  Unité                   357 non-null    object
#  11  Valeur                  357 non-null    int64
#  12  Symbole                 357 non-null    object
#  13  Description du Symbole  357 non-null    object
# dtypes: int64(6), object(8)
# memory usage: 39.2+ KB

# %%
df_population = df_population[['Code zone', 'Zone', 'Produit', 'Année', 'Valeur']]
df_population['Valeur'] = df_population['Valeur']*1000
df_population.head()
# Out:
#    Code zone            Zone     Produit  Année    Valeur
# 0          2     Afghanistan  Population   2013  32270000
# 1          2     Afghanistan  Population   2019  38042000
# 2        202  Afrique du Sud  Population   2013  53687000
# 3        202  Afrique du Sud  Population   2019  58558000
# 4          3         Albanie  Population   2013   2904000

# %%
df_population = df_population.pivot_table(index=['Code zone', 'Zone', 'Produit'], columns='Année', values = 'Valeur', aggfunc = sum).reset_index()

# %%
# différence de population entre 2013 et 2019, exprimée en pourcentage
df_population['Evolution population (%)'] = round(((df_population[2019]-df_population[2013])/df_population[2013])*100,3)

# %%
df_population.head()
# Out:
# Année  Code zone         Zone     Produit        2013        2019  \
# 0              1      Arménie  Population   2898000.0   2958000.0
# 1              2  Afghanistan  Population  32270000.0  38042000.0
# 2              3      Albanie  Population   2904000.0   2881000.0
# 3              4      Algérie  Population  38140000.0  43053000.0
# 4              7       Angola  Population  26016000.0  31825000.0
#
# Année  Evolution population (%)
# 0                         2.070
# 1                        17.887
# 2                        -0.792
# 3                        12.881
# 4                        22.329

# %%
population2013 = df_population[2013].sum()
population2019 = df_population[2019].sum()
evolution_globale = round(((population2017 - population2013) / population2013)*100,3)
print('Pour indication, la population totale en 2013 était de', population2013, 'et de', population2019, 'en 2019.\nL\'évolution 2015/2017 est de', evolution_globale, '%.')
# Out:
# Pour indication, la population totale en 2013 était de 8564484000.0 et de 9108256000.0 en 2019.
# L'évolution 2015/2017 est de 6.349 %.

# %%
df_dispo_alimentaire = pd.read_csv('datas/disponibilite_alimentaire_2019.csv', header=0, sep=",", decimal=".")
df_dispo_alimentaire.head()
# Out:
#   Code Domaine                      Domaine  Code zone         Zone  \
# 0          FBS  Bilans Alimentaires (2010-)          2  Afghanistan
# 1          FBS  Bilans Alimentaires (2010-)          2  Afghanistan
# 2          FBS  Bilans Alimentaires (2010-)          2  Afghanistan
# 3          FBS  Bilans Alimentaires (2010-)          2  Afghanistan
# 4          FBS  Bilans Alimentaires (2010-)          2  Afghanistan
#
#    Code Élément                                            Élément  \
# 0           664     Disponibilité alimentaire (Kcal/personne/jour)
# 1           674  Disponibilité de protéines en quantité (g/pers...
# 2           684  Disponibilité de matière grasse en quantité (g...
# 3           664     Disponibilité alimentaire (Kcal/personne/jour)
# 4           674  Disponibilité de protéines en quantité (g/pers...
#
#    Code Produit           Produit  Code année  Année               Unité  \
# 0          2901     Total General        2019   2019  Kcal/personne/jour
# 1          2901     Total General        2019   2019     g/personne/jour
# 2          2901     Total General        2019   2019     g/personne/jour
# 3          2941  Produits Animaux        2019   2019  Kcal/personne/jour
# 4          2941  Produits Animaux        2019   2019     g/personne/jour
#
#     Valeur Symbole Description du Symbole
# 0  2273.00      Fc        Donnée calculée
# 1    57.31      Fc        Donnée calculée
# 2    39.78      Fc        Donnée calculée
# 3   187.00      Fc        Donnée calculée
# 4    10.34      Fc        Donnée calculée

# %% [markdown]
# # 2. Données sur les bilans alimentaires mondiaux (2019)

# %%
df_dispo_alimentaire = pd.read_csv('datas/disponibilite_alimentaire_2019.csv', header=0, sep=",", decimal=".")
df_dispo_alimentaire.head()
# Out:
#   Code Domaine                      Domaine  Code zone         Zone  \
# 0          FBS  Bilans Alimentaires (2010-)          2  Afghanistan
# 1          FBS  Bilans Alimentaires (2010-)          2  Afghanistan
# 2          FBS  Bilans Alimentaires (2010-)          2  Afghanistan
# 3          FBS  Bilans Alimentaires (2010-)          2  Afghanistan
# 4          FBS  Bilans Alimentaires (2010-)          2  Afghanistan
#
#    Code Élément                                            Élément  \
# 0           664     Disponibilité alimentaire (Kcal/personne/jour)
# 1           674  Disponibilité de protéines en quantité (g/pers...
# 2           684  Disponibilité de matière grasse en quantité (g...
# 3           664     Disponibilité alimentaire (Kcal/personne/jour)
# 4           674  Disponibilité de protéines en quantité (g/pers...
#
#    Code Produit           Produit  Code année  Année               Unité  \
# 0          2901     Total General        2019   2019  Kcal/personne/jour
# 1          2901     Total General        2019   2019     g/personne/jour
# 2          2901     Total General        2019   2019     g/personne/jour
# 3          2941  Produits Animaux        2019   2019  Kcal/personne/jour
# 4          2941  Produits Animaux        2019   2019     g/personne/jour
#
#     Valeur Symbole Description du Symbole
# 0  2273.00      Fc        Donnée calculée
# 1    57.31      Fc        Donnée calculée
# 2    39.78      Fc        Donnée calculée
# 3   187.00      Fc        Donnée calculée
# 4    10.34      Fc        Donnée calculée

# %%
df_dispo_alimentaire = df_dispo_alimentaire.pivot_table(index=['Code zone', 'Zone', 'Année'],
                                columns=['Élément', 'Produit'],
                                values = 'Valeur',
                                aggfunc=sum).reset_index()
df_dispo_alimentaire.head()
# Out:
# Élément Code zone         Zone Année  \
# Produit
# 0               1      Arménie  2019
# 1               2  Afghanistan  2019
# 2               3      Albanie  2019
# 3               4      Algérie  2019
# 4               7       Angola  2019
#
# Élément Disponibilité alimentaire (Kcal/personne/jour)                \
# Produit                               Produits Animaux Total General
# 0                                                975.0        3022.0
# 1                                                187.0        2273.0
# 2                                               1021.0        3338.0
# 3                                                379.0        3493.0
# 4                                                211.0        2445.0
#
# Élément Disponibilité de matière grasse en quantité (g/personne/jour)  \
# Produit                                              Produits Animaux
# 0                                                    74.06
# 1                                                    12.67
# 2                                                    70.01
# 3                                                    22.14
# 4                                                    15.27
#
# Élément                \
# Produit Total General
# 0              115.83
# 1               39.78
# 2              115.99
# 3               98.14
# 4               59.42
#
# Élément Disponibilité de protéines en quantité (g/personne/jour)
# Produit                                         Produits Animaux Total General
# 0                                                    52.86               94.29
# 1                                                    10.34               57.31
# 2                                                    62.47              116.02
# 3                                                    24.09               90.84
# 4                                                    15.54               52.09

# %%
df_dispo_alimentaire_pop = pd.merge(df_population, df_dispo_alimentaire, on="Code zone")
df_dispo_alimentaire_pop
# Out:
# /Users/rowaidakanaan/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py:648: UserWarning: merging between different levels can give an unintended result (1 levels on the left,2 on the right)
#   warnings.warn(msg, UserWarning)
# /Users/rowaidakanaan/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:4153: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#      Code zone         Zone     Produit          2013          2019  \
# 0            1      Arménie  Population  2.898000e+06  2.958000e+06
# 1            2  Afghanistan  Population  3.227000e+07  3.804200e+07
# 2            3      Albanie  Population  2.904000e+06  2.881000e+06
# 3            4      Algérie  Population  3.814000e+07  4.305300e+07
# 4            7       Angola  Population  2.601600e+07  3.182500e+07
# ..         ...          ...         ...           ...           ...
# 174        256   Luxembourg  Population  5.300000e+05  6.160000e+05
# 175        272       Serbie  Population  9.511000e+06  8.772000e+06
# 176        273   Monténégro  Population  6.260000e+05  6.280000e+05
# 177        276       Soudan  Population  3.707300e+07  4.281300e+07
# 178        351        Chine  Population  1.422971e+09  1.465634e+09
#
#      Evolution population (%)     (Zone, )  (Année, )  \
# 0                       2.070      Arménie       2019
# 1                      17.887  Afghanistan       2019
# 2                      -0.792      Albanie       2019
# 3                      12.881      Algérie       2019
# 4                      22.329       Angola       2019
# ..                        ...          ...        ...
# 174                    16.226   Luxembourg       2019
# 175                    -7.770       Serbie       2019
# 176                     0.319   Monténégro       2019
# 177                    15.483       Soudan       2019
# 178                     2.998        Chine       2019
#
#      (Disponibilité alimentaire (Kcal/personne/jour), Produits Animaux)  \
# 0                                                975.0
# 1                                                187.0
# 2                                               1021.0
# 3                                                379.0
# 4                                                211.0
# ..                                                 ...
# 174                                             1184.0
# 175                                              817.0
# 176                                             1227.0
# 177                                              353.0
# 178                                              754.0
#
#      (Disponibilité alimentaire (Kcal/personne/jour), Total General)  \
# 0                                               3022.0
# 1                                               2273.0
# 2                                               3338.0
# 3                                               3493.0
# 4                                               2445.0
# ..                                                 ...
# 174                                             3504.0
# 175                                             2865.0
# 176                                             3520.0
# 177                                             2581.0
# 178                                             3340.0
#
#      (Disponibilité de matière grasse en quantité (g/personne/jour), Produits Animaux)  \
# 0                                                74.06
# 1                                                12.67
# 2                                                70.01
# 3                                                22.14
# 4                                                15.27
# ..                                                 ...
# 174                                              92.36
# 175                                              61.78
# 176                                              93.32
# 177                                              24.88
# 178                                              60.91
#
#      (Disponibilité de matière grasse en quantité (g/personne/jour), Total General)  \
# 0                                               115.83
# 1                                                39.78
# 2                                               115.99
# 3                                                98.14
# 4                                                59.42
# ..                                                 ...
# 174                                             144.14
# 175                                              89.85
# 176                                             143.02
# 177                                              68.35
# 178                                             105.77
#
#      (Disponibilité de protéines en quantité (g/personne/jour), Produits Animaux)  \
# 0                                                52.86
# 1                                                10.34
# 2                                                62.47
# 3                                                24.09
# 4                                                15.54
# ..                                                 ...
# 174                                              66.55
# 175                                              43.79
# 176                                              67.47
# 177                                              19.92
# 178                                              41.62
#
#      (Disponibilité de protéines en quantité (g/personne/jour), Total General)
# 0                                                94.29
# 1                                                57.31
# 2                                               116.02
# 3                                                90.84
# 4                                                52.09
# ..                                                 ...
# 174                                             108.95
# 175                                              86.58
# 176                                             111.99
# 177                                              75.87
# 178                                             105.11
#
# [179 rows x 14 columns]

# %%
# proportion de protéines d'origine animale par rapport à la quantité totale de protéines dans la disponibilité alimentaire du pays
df_dispo_alimentaire_pop["Prot. Animales/Prot. Totales dispo (%)"] = round((df_dispo_alimentaire_pop[('Disponibilité de protéines en quantité (g/personne/jour)', 'Produits Animaux')]
                                                                         /df_dispo_alimentaire_pop[('Disponibilité de protéines en quantité (g/personne/jour)', 'Total General')])*100,3)

# %%
df_dispo_alimentaire_pop = df_dispo_alimentaire_pop[["Code zone","Zone", ('Année', ''), 2019, "Evolution population (%)",
                                             ('Disponibilité alimentaire (Kcal/personne/jour)', 'Total General'),
                                             ('Disponibilité de protéines en quantité (g/personne/jour)', 'Total General'),
                                             'Prot. Animales/Prot. Totales dispo (%)']]
# Out:
# /Users/rowaidakanaan/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)

# %%
df_dispo_alimentaire_pop.rename(columns={('Année', ''):'Année', 2019:'Population', 
                              ('Disponibilité alimentaire (Kcal/personne/jour)', 'Total General'):'Dispo. Alim. (Kcal/personne)',
                              ('Disponibilité de protéines en quantité (g/personne/jour)', 'Total General'):'Dispo. Prot. (g/personne)'},
                     inplace=True)
# Out:
# /Users/rowaidakanaan/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df_dispo_alimentaire_pop
# Out:
#      Code zone         Zone  Année    Population  Evolution population (%)  \
# 0            1      Arménie   2019  2.958000e+06                     2.070
# 1            2  Afghanistan   2019  3.804200e+07                    17.887
# 2            3      Albanie   2019  2.881000e+06                    -0.792
# 3            4      Algérie   2019  4.305300e+07                    12.881
# 4            7       Angola   2019  3.182500e+07                    22.329
# ..         ...          ...    ...           ...                       ...
# 174        256   Luxembourg   2019  6.160000e+05                    16.226
# 175        272       Serbie   2019  8.772000e+06                    -7.770
# 176        273   Monténégro   2019  6.280000e+05                     0.319
# 177        276       Soudan   2019  4.281300e+07                    15.483
# 178        351        Chine   2019  1.465634e+09                     2.998
#
#      Dispo. Alim. (Kcal/personne)  Dispo. Prot. (g/personne)  \
# 0                          3022.0                      94.29
# 1                          2273.0                      57.31
# 2                          3338.0                     116.02
# 3                          3493.0                      90.84
# 4                          2445.0                      52.09
# ..                            ...                        ...
# 174                        3504.0                     108.95
# 175                        2865.0                      86.58
# 176                        3520.0                     111.99
# 177                        2581.0                      75.87
# 178                        3340.0                     105.11
#
#      Prot. Animales/Prot. Totales dispo (%)
# 0                                    56.061
# 1                                    18.042
# 2                                    53.844
# 3                                    26.519
# 4                                    29.833
# ..                                      ...
# 174                                  61.083
# 175                                  50.578
# 176                                  60.246
# 177                                  26.255
# 178                                  39.597
#
# [179 rows x 8 columns]
