# %% [markdown]
# # Produisez une étude de marché

# %% [markdown]
# # Scénario
# Votre entreprise **d'agroalimentaire** souhaite se développer à l'international. Elle est spécialisée dans...
#  le poulet !
#
# L'international, oui, mais pour l'instant, le champ des possibles est bien large : aucun pays particulier ni aucun continent n'est pour le moment choisi. Tous les pays sont envisageables !
#
# Votre objectif sera d'aider **à cibler plus particulièrement certains pays**, dans le but d'approfondir ensuite l'étude de marché. Plus particulièrement, l'idéal serait de produire des "groupes" de pays, plus ou moins gros, dont on connaît les caractéristiques.
#
# Dans un premier temps, la stratégie est plutôt d'exporter les produits plutôt que de produire sur place, c'est-à-dire dans le(s) nouveau(x) pays ciblé(s).

# %% [markdown]
# Pour identifier les pays propices à une insertion dans le marché du poulet,
#  Il vous a été demandé de cibler les pays.
#  Etudier les régimes alimentaires de chaque pays, notamment en termes de protéines d'origine animale et en termes de calories.
#
#
# Construisez votre échantillon contenant l'ensemble des pays disponibles, chacun caractérisé par ces variables :
#
# différence de population entre une année antérieure (au choix) et l'année courante, exprimée en pourcentage ;
# proportion de protéines d'origine animale par rapport à la quantité totale de protéines dans la disponibilité alimentaire du pays ;
# disponibilité alimentaire en protéines par habitant ;
# disponibilité alimentaire en calories par habitant.
#
# Construisez un dendrogramme contenant l'ensemble des pays étudiés, puis coupez-le afin d'obtenir 5 groupes.
#
# Caractérisez chacun de ces groupes selon les variables cités précédemment, et facultativement selon d'autres variables que vous jugerez pertinentes (ex : le PIB par habitant). Vous pouvez le faire en calculant la position des centroïdes de chacun des groupes, puis en les commentant et en les critiquant au vu de vos objectifs.
#
# Donnez une courte liste de pays à cibler, en présentant leurs caractéristiques. Un découpage plus précis qu'en 5 groupes peut si besoin être effectué pour cibler un nombre raisonnable de pays.
#
# Visualisez vos  partitions dans le premier plan factoriel obtenu par ACP.
#
# Dans votre partition, vous avez obtenu des groupes distincts. Vérifiez donc qu'ils diffèrent réellement. Pour cela, réalisez les tests statistiques suivants :
#
# un test d'adéquation : parmi les 4 variables, ou parmi d'autres variables que vous trouverez pertinentes, trouvez une variable dont la loi est normale ;
# un test de comparaison de deux populations (dans le cas gaussien) : choisissez 2 clusters parmi ceux que vous aurez déterminé. Sur ces 2 clusters, testez la variable gaussienne grâce à un test de comparaison.

# %%
# Librairies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import seaborn as sns
import sklearn as sk
import scipy as sp
import pca as pca

# %%
#Versions utilisées
print("Jupyter Notebook : " + str(pd.__version__))
print("Pandas : " + str(pd.__version__))
print("Numpy : " + str(np.__version__))
print("Seaborn : " + str(sns.__version__))
# Out:
# Jupyter Notebook : 1.2.4
# Pandas : 1.2.4
# Numpy : 1.20.1
# Seaborn : 0.11.1

# %%
sns.set( # Styles Seaborn
    style='whitegrid',
    context='notebook',
    palette='Paired',
    rc={'figure.figsize':(8,5)})

# %%
# Couleurs
red_a400 = '#ff1744'
indigo_a100 = '#8c9eff'
indigo_a400 = '#3d5afe'
indigo_a700 = '#304ffe'
bluegrey_900 = '#263238'
teal_a400 = '#1de9b6'
purple_a400 = '#d500f9'
yellow_a400 = '#ffea00'
bluegrey_900 = '#263238'
palette_5 = [teal_a400, indigo_a400, red_a400, yellow_a400, purple_a400]

# %% [markdown]
# # 1. Import des données

# %% [markdown]
# ## 1.1 Import et traitement de la population par pays
# la variation de la population entre 2013 et 2019, en %, qui sera positive en cas de croissance ou négative en cas de baisse démographique ;

# %%
df_population = pd.read_csv('datas/fao-populations_2019- 2013.csv' , header=0, sep=",", decimal=".")
df_population.head(2)
# Out:
#   Code Domaine                      Domaine  Code zone         Zone  \
# 0          FBS  Bilans Alimentaires (2010-)          2  Afghanistan
# 1          FBS  Bilans Alimentaires (2010-)          2  Afghanistan
#
#    Code Élément            Élément  Code Produit     Produit  Code année  \
# 0           511  Population totale          2501  Population        2013
# 1           511  Population totale          2501  Population        2019
#
#    Année           Unité  Valeur Symbole Description du Symbole
# 0   2013  1000 personnes   32270       *   Chiffre non officiel
# 1   2019  1000 personnes   38042       *   Chiffre non officiel

# %%
df_population = df_population[['Code zone', 'Zone', 'Produit', 'Année', 'Valeur']]
df_population['Valeur'] = df_population['Valeur']*1000
df_population.head()
# Out:
#    Code zone            Zone     Produit  Année    Valeur
# 0          2     Afghanistan  Population   2013  32270000
# 1          2     Afghanistan  Population   2019  38042000
# 2        202  Afrique du Sud  Population   2013  53687000
# 3        202  Afrique du Sud  Population   2019  58558000
# 4          3         Albanie  Population   2013   2904000

# %%
df_population = df_population.pivot_table(index=['Code zone', 'Zone'], columns='Année', values = 'Valeur', aggfunc = sum).reset_index()
df_population.head()
# Out:
# Année  Code zone         Zone        2013        2019
# 0              1      Arménie   2898000.0   2958000.0
# 1              2  Afghanistan  32270000.0  38042000.0
# 2              3      Albanie   2904000.0   2881000.0
# 3              4      Algérie  38140000.0  43053000.0
# 4              7       Angola  26016000.0  31825000.0

# %%
# différence de population entre 2013 et 2019, exprimée en pourcentage
df_population['Evolution population (%)'] = round(((df_population[2019]-df_population[2013])/df_population[2013])*100,3)

# %%
df_population.head(20)
# Out:
# Année  Code zone                             Zone         2013         2019  \
# 0              1                          Arménie    2898000.0    2958000.0
# 1              2                      Afghanistan   32270000.0   38042000.0
# 2              3                          Albanie    2904000.0    2881000.0
# 3              4                          Algérie   38140000.0   43053000.0
# 4              7                           Angola   26016000.0   31825000.0
# 5              8               Antigua-et-Barbuda      92000.0      97000.0
# 6              9                        Argentine   42196000.0   44781000.0
# 7             10                        Australie   23255000.0   25203000.0
# 8             11                         Autriche    8556000.0    8955000.0
# 9             12                          Bahamas     367000.0     389000.0
# 10            14                          Barbade     284000.0     287000.0
# 11            16                       Bangladesh  152761000.0  163046000.0
# 12            19  Bolivie (État plurinational de)   10542000.0   11513000.0
# 13            20                         Botswana    2063000.0    2304000.0
# 14            21                           Brésil  201036000.0  211050000.0
# 15            23                           Belize     346000.0     390000.0
# 16            25                     Îles Salomon     571000.0     670000.0
# 17            27                         Bulgarie    7290000.0    7000000.0
# 18            28                          Myanmar   51852000.0   54045000.0
# 19            29                          Burundi          NaN   11531000.0
#
# Année  Evolution population (%)
# 0                         2.070
# 1                        17.887
# 2                        -0.792
# 3                        12.881
# 4                        22.329
# 5                         5.435
# 6                         6.126
# 7                         8.377
# 8                         4.663
# 9                         5.995
# 10                        1.056
# 11                        6.733
# 12                        9.211
# 13                       11.682
# 14                        4.981
# 15                       12.717
# 16                       17.338
# 17                       -3.978
# 18                        4.229
# 19                          NaN

# %%
population2013 = df_population[2013].sum()
population2019 = df_population[2019].sum()
evolution_globale = round(((population2019 - population2013) / population2013)*100,3)
print('Pour indication, la population totale en 2013 était de', population2013, 'et de', population2019, 'en 2019.\nL\'évolution 2013/2019 est de', evolution_globale, '%.')
# Out:
# Pour indication, la population totale en 2013 était de 8564484000.0 et de 9108256000.0 en 2019.
# L'évolution 2013/2019 est de 6.349 %.

# %%
df_population= df_population.rename(columns= {2019: 'population'})
df_population= df_population[['Code zone', 'Zone' , 'population' ,'Evolution population (%)']]
df_population.head(2)
# Out:
# Année  Code zone         Zone  population  Evolution population (%)
# 0              1      Arménie   2958000.0                     2.070
# 1              2  Afghanistan  38042000.0                    17.887

# %% [markdown]
# ## 2.1 Données sur les bilans alimentaires mondiaux (2019)

# %% [markdown]
# le ratio entre la quantité de protéines d’origine animale et la quantité totale de protéines consommées ;

# %%
df_dispo_alimentaire = pd.read_csv('datas/FAOSTAT_data.csv', header=0, sep=",", decimal=".")
df_dispo_alimentaire.head(4)
# Out:
#   Code Domaine                      Domaine  Code zone         Zone  \
# 0          FBS  Bilans Alimentaires (2010-)          2  Afghanistan
# 1          FBS  Bilans Alimentaires (2010-)          2  Afghanistan
# 2          FBS  Bilans Alimentaires (2010-)          2  Afghanistan
# 3          FBS  Bilans Alimentaires (2010-)          2  Afghanistan
#
#    Code Élément                                            Élément  \
# 0           664     Disponibilité alimentaire (Kcal/personne/jour)
# 1           674  Disponibilité de protéines en quantité (g/pers...
# 2           684  Disponibilité de matière grasse en quantité (g...
# 3           664     Disponibilité alimentaire (Kcal/personne/jour)
#
#    Code Produit           Produit  Code année  Année               Unité  \
# 0          2901     Total General        2019   2019  Kcal/personne/jour
# 1          2901     Total General        2019   2019     g/personne/jour
# 2          2901     Total General        2019   2019     g/personne/jour
# 3          2941  Produits Animaux        2019   2019  Kcal/personne/jour
#
#     Valeur Symbole Description du Symbole
# 0  2273.00      Fc        Donnée calculée
# 1    57.31      Fc        Donnée calculée
# 2    39.78      Fc        Donnée calculée
# 3   187.00      Fc        Donnée calculée

# %%
df_dispo_alimentaire = df_dispo_alimentaire.pivot_table(index=['Code zone', 'Zone', 'Année'],
                                columns=['Élément', 'Produit'],
                                values = 'Valeur',
                                aggfunc=sum).reset_index()
df_dispo_alimentaire.head()
# Out:
# Élément Code zone         Zone Année  \
# Produit
# 0               1      Arménie  2019
# 1               2  Afghanistan  2019
# 2               3      Albanie  2019
# 3               4      Algérie  2019
# 4               7       Angola  2019
#
# Élément Disponibilité alimentaire (Kcal/personne/jour)                \
# Produit                               Produits Animaux Total General
# 0                                                975.0        3022.0
# 1                                                187.0        2273.0
# 2                                               1021.0        3338.0
# 3                                                379.0        3493.0
# 4                                                211.0        2445.0
#
# Élément Disponibilité de matière grasse en quantité (g/personne/jour)  \
# Produit                                              Produits Animaux
# 0                                                    74.06
# 1                                                    12.67
# 2                                                    70.01
# 3                                                    22.14
# 4                                                    15.27
#
# Élément                \
# Produit Total General
# 0              115.83
# 1               39.78
# 2              115.99
# 3               98.14
# 4               59.42
#
# Élément Disponibilité de protéines en quantité (g/personne/jour)
# Produit                                         Produits Animaux Total General
# 0                                                    52.86               94.29
# 1                                                    10.34               57.31
# 2                                                    62.47              116.02
# 3                                                    24.09               90.84
# 4                                                    15.54               52.09

# %%
# proportion de protéines d'origine animale par rapport à la quantité totale de protéines dans la disponibilité alimentaire du pays
df_dispo_alimentaire["ratio_proteines_animales"] = round((df_dispo_alimentaire[('Disponibilité de protéines en quantité (g/personne/jour)', 'Produits Animaux')]
                                                                         /df_dispo_alimentaire[('Disponibilité de protéines en quantité (g/personne/jour)', 'Total General')])*100,3)
df_dispo_alimentaire.head()
# Out:
# Élément Code zone         Zone Année  \
# Produit
# 0               1      Arménie  2019
# 1               2  Afghanistan  2019
# 2               3      Albanie  2019
# 3               4      Algérie  2019
# 4               7       Angola  2019
#
# Élément Disponibilité alimentaire (Kcal/personne/jour)                \
# Produit                               Produits Animaux Total General
# 0                                                975.0        3022.0
# 1                                                187.0        2273.0
# 2                                               1021.0        3338.0
# 3                                                379.0        3493.0
# 4                                                211.0        2445.0
#
# Élément Disponibilité de matière grasse en quantité (g/personne/jour)  \
# Produit                                              Produits Animaux
# 0                                                    74.06
# 1                                                    12.67
# 2                                                    70.01
# 3                                                    22.14
# 4                                                    15.27
#
# Élément                \
# Produit Total General
# 0              115.83
# 1               39.78
# 2              115.99
# 3               98.14
# 4               59.42
#
# Élément Disponibilité de protéines en quantité (g/personne/jour)  \
# Produit                                         Produits Animaux
# 0                                                    52.86
# 1                                                    10.34
# 2                                                    62.47
# 3                                                    24.09
# 4                                                    15.54
#
# Élément               ratio_proteines_animales
# Produit Total General
# 0               94.29                   56.061
# 1               57.31                   18.042
# 2              116.02                   53.844
# 3               90.84                   26.519
# 4               52.09                   29.833

# %% [markdown]
# ## 3.1  les valeurs de PIB par habitant,
# en $ paritaire, c’est à dire normalisé en fonction du coût de la vie.

# %%
# Dataframes des données complémentaires
# Indicateurs Macro (PIB et croissance)
df_indicateurs_macro = pd.read_csv('datas/indicateurs_macro.csv', header=0, sep=',', decimal='.')

df_indicateurs_macro.head()
# Out:
#   Code Domaine            Domaine  Code zone (FAO)            Zone  \
# 0           MK  Indicateurs macro                2     Afghanistan
# 1           MK  Indicateurs macro                2     Afghanistan
# 2           MK  Indicateurs macro                2     Afghanistan
# 3           MK  Indicateurs macro              202  Afrique du Sud
# 4           MK  Indicateurs macro              202  Afrique du Sud
#
#    Code Élément                               Élément  Code Produit  \
# 0          6110                           Valeur US $         22008
# 1          6119              Valeur US $ par habitant         22008
# 2         61290  Croissance annuelle US$ par habitant         22008
# 3          6110                           Valeur US $         22008
# 4          6119              Valeur US $ par habitant         22008
#
#                   Produit  Code année  Année     Unité         Valeur Symbole  \
# 0  Produit Intérieur Brut        2019   2019  millions   17876.546427       X
# 1  Produit Intérieur Brut        2019   2019       US$     469.919090       X
# 2  Produit Intérieur Brut        2019   2019         %      -2.886380      Fc
# 3  Produit Intérieur Brut        2019   2019  millions  351430.991183       X
# 4  Produit Intérieur Brut        2019   2019       US$    6001.389576       X
#
#           Description du Symbole  Note
# 0  Sources internationales sûres   NaN
# 1  Sources internationales sûres   NaN
# 2                Donnée calculée   NaN
# 3  Sources internationales sûres   NaN
# 4  Sources internationales sûres   NaN

# %%
df_indicateurs_macro = df_indicateurs_macro[['Code zone (FAO)','Élément','Valeur','Produit']]
                             
df_indicateurs_macro.head()
# Out:
#    Code zone (FAO)                               Élément         Valeur  \
# 0                2                           Valeur US $   17876.546427
# 1                2              Valeur US $ par habitant     469.919090
# 2                2  Croissance annuelle US$ par habitant      -2.886380
# 3              202                           Valeur US $  351430.991183
# 4              202              Valeur US $ par habitant    6001.389576
#
#                   Produit
# 0  Produit Intérieur Brut
# 1  Produit Intérieur Brut
# 2  Produit Intérieur Brut
# 3  Produit Intérieur Brut
# 4  Produit Intérieur Brut

# %%
df_indicateurs_macro = df_indicateurs_macro.pivot_table(index=['Code zone (FAO)'], columns='Élément', values='Valeur', aggfunc=sum).reset_index()
df_indicateurs_macro.head()
# Out:
# Élément  Code zone (FAO)  Croissance annuelle US$ par habitant    Valeur US $  \
# 0                      1                              9.529576   13672.801339
# 1                      2                             -2.886380   17876.546427
# 2                      3                              0.928996   15278.072762
# 3                      4                             -4.295828  171157.863119
# 4                      6                             -2.170092    3154.137481
#
# Élément  Valeur US $ par habitant
# 0                     4622.733216
# 1                      469.919090
# 2                     5303.197823
# 3                     3975.510381
# 4                    40887.421647

# %%
df_indicateurs_macro = df_indicateurs_macro.rename(columns={"Croissance annuelle US$":"Croissance annuelle PIB US$ (%)",
                                    "Valeur US $":"PIB Total US$ (Millions)",'Code zone (FAO)':'Code zone', 'Valeur US $ par habitant': 'PIB par habitant'})
df_indicateurs_macro.head()
# Out:
# Élément  Code zone  Croissance annuelle US$ par habitant  \
# 0                1                              9.529576
# 1                2                             -2.886380
# 2                3                              0.928996
# 3                4                             -4.295828
# 4                6                             -2.170092
#
# Élément  PIB Total US$ (Millions)  PIB par habitant
# 0                    13672.801339       4622.733216
# 1                    17876.546427        469.919090
# 2                    15278.072762       5303.197823
# 3                   171157.863119       3975.510381
# 4                     3154.137481      40887.421647

# %% [markdown]
# ## 4.1 Le taux de dépendance aux importations,
# défini en économie comme le rapport entre les importations et la disponibilité intérieure du pays ;

# %%
df_dépendance_importations = pd.read_csv('datas/la viande de volailles.csv', header=0, sep=",", decimal=".")
df_dépendance_importations.head(3)
# Out:
#   Code Domaine                      Domaine  Code zone         Zone  \
# 0          FBS  Bilans Alimentaires (2010-)          2  Afghanistan
# 1          FBS  Bilans Alimentaires (2010-)          2  Afghanistan
# 2          FBS  Bilans Alimentaires (2010-)          2  Afghanistan
#
#    Code Élément                   Élément  Code Produit              Produit  \
# 0          5511                Production          2734  Viande de Volailles
# 1          5611   Importations - Quantité          2734  Viande de Volailles
# 2          5301  Disponibilité intérieure          2734  Viande de Volailles
#
#    Code année  Année               Unité  Valeur Symbole  \
# 0        2019   2019  Milliers de tonnes      28      Im
# 1        2019   2019  Milliers de tonnes      44      Im
# 2        2019   2019  Milliers de tonnes      67       S
#
#                               Description du Symbole
# 0  Données de la FAO basées sur une méthodologie ...
# 1  Données de la FAO basées sur une méthodologie ...
# 2                              Données standardisées

# %%
df_dépendance_importations['Valeur'] = df_dépendance_importations['Valeur']*1000000
df_dépendance_importations.head(3)
# Out:
#   Code Domaine                      Domaine  Code zone         Zone  \
# 0          FBS  Bilans Alimentaires (2010-)          2  Afghanistan
# 1          FBS  Bilans Alimentaires (2010-)          2  Afghanistan
# 2          FBS  Bilans Alimentaires (2010-)          2  Afghanistan
#
#    Code Élément                   Élément  Code Produit              Produit  \
# 0          5511                Production          2734  Viande de Volailles
# 1          5611   Importations - Quantité          2734  Viande de Volailles
# 2          5301  Disponibilité intérieure          2734  Viande de Volailles
#
#    Code année  Année               Unité    Valeur Symbole  \
# 0        2019   2019  Milliers de tonnes  28000000      Im
# 1        2019   2019  Milliers de tonnes  44000000      Im
# 2        2019   2019  Milliers de tonnes  67000000       S
#
#                               Description du Symbole
# 0  Données de la FAO basées sur une méthodologie ...
# 1  Données de la FAO basées sur une méthodologie ...
# 2                              Données standardisées

# %%
df_dépendance_importations = df_dépendance_importations.pivot_table(index=['Code zone', 'Zone', 'Année'],
                                columns=['Élément'],
                                values = 'Valeur',
                                aggfunc=sum).reset_index()
df_dépendance_importations
# Out:
# Élément  Code zone         Zone  Année  Disponibilité intérieure  \
# 0                1      Arménie   2019              5.500000e+07
# 1                2  Afghanistan   2019              6.700000e+07
# 2                3      Albanie   2019              3.400000e+07
# 3                4      Algérie   2019              2.870000e+08
# 4                7       Angola   2019              3.270000e+08
# ..             ...          ...    ...                       ...
# 174            256   Luxembourg   2019              1.200000e+07
# 175            272       Serbie   2019              1.120000e+08
# 176            273   Monténégro   2019              1.000000e+07
# 177            276       Soudan   2019              5.600000e+07
# 178            351        Chine   2019              2.138600e+10
#
# Élément  Importations - Quantité    Production
# 0                   4.300000e+07  1.200000e+07
# 1                   4.400000e+07  2.800000e+07
# 2                   2.200000e+07  1.200000e+07
# 3                   0.000000e+00  2.910000e+08
# 4                   2.780000e+08  4.900000e+07
# ..                           ...           ...
# 174                 1.200000e+07  0.000000e+00
# 175                 1.700000e+07  1.040000e+08
# 176                 7.000000e+06  4.000000e+06
# 177                 0.000000e+00  7.500000e+07
# 178                 1.814000e+09  2.119500e+10
#
# [179 rows x 6 columns]

# %%
df_dépendance_importations['taux_dépendance_importations']=df_dépendance_importations['Importations - Quantité']    / df_dépendance_importations['Disponibilité intérieure']*100
df_dépendance_importations.head(2)
# Out:
# Élément  Code zone         Zone  Année  Disponibilité intérieure  \
# 0                1      Arménie   2019                55000000.0
# 1                2  Afghanistan   2019                67000000.0
#
# Élément  Importations - Quantité  Production  taux_dépendance_importations
# 0                     43000000.0  12000000.0                     78.181818
# 1                     44000000.0  28000000.0                     65.671642

# %%
df_dépendance_importations = df_dépendance_importations[['Code zone', 'Disponibilité intérieure','Importations - Quantité', 'Production','taux_dépendance_importations']]

# %% [markdown]
# ## 5.1 Construction et sauvegarde du dataframe principal

# %%
df_dispo_alimentaire_etendu = pd.merge(df_population, df_dispo_alimentaire, on="Code zone")

df_dispo_alimentaire_etendu.head(2)
# Out:
# /Users/rowaidakanaan/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py:648: UserWarning: merging between different levels can give an unintended result (1 levels on the left,2 on the right)
#   warnings.warn(msg, UserWarning)
# /Users/rowaidakanaan/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:4153: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    Code zone         Zone  population  Evolution population (%)     (Zone, )  \
# 0          1      Arménie   2958000.0                     2.070      Arménie
# 1          2  Afghanistan  38042000.0                    17.887  Afghanistan
#
#    (Année, )  \
# 0       2019
# 1       2019
#
#    (Disponibilité alimentaire (Kcal/personne/jour), Produits Animaux)  \
# 0                                              975.0
# 1                                              187.0
#
#    (Disponibilité alimentaire (Kcal/personne/jour), Total General)  \
# 0                                             3022.0
# 1                                             2273.0
#
#    (Disponibilité de matière grasse en quantité (g/personne/jour), Produits Animaux)  \
# 0                                              74.06
# 1                                              12.67
#
#    (Disponibilité de matière grasse en quantité (g/personne/jour), Total General)  \
# 0                                             115.83
# 1                                              39.78
#
#    (Disponibilité de protéines en quantité (g/personne/jour), Produits Animaux)  \
# 0                                              52.86
# 1                                              10.34
#
#    (Disponibilité de protéines en quantité (g/personne/jour), Total General)  \
# 0                                              94.29
# 1                                              57.31
#
#    (ratio_proteines_animales, )
# 0                        56.061
# 1                        18.042

# %%
df_dispo_alimentaire_etendu = df_dispo_alimentaire_etendu[["Code zone","Zone", ('Année', ''), 'population','Evolution population (%)',
                                             ('Disponibilité alimentaire (Kcal/personne/jour)', 'Total General'),
                                             ('Disponibilité de protéines en quantité (g/personne/jour)', 'Total General'),
                                            ('ratio_proteines_animales', '')
]]
df_dispo_alimentaire_etendu.rename(columns={('Année', ''):'Année', 
                              ('Disponibilité alimentaire (Kcal/personne/jour)', 'Total General'):'dispo_calories',
                              ('Disponibilité de protéines en quantité (g/personne/jour)', 'Total General'):'dispo_proteines',  ('ratio_proteines_animales', ''):'ratio_proteines_animales'},
                     inplace=True)
df_dispo_alimentaire_etendu.head()
# Out:
# /Users/rowaidakanaan/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)
#    Code zone         Zone  Année  population  Evolution population (%)  \
# 0          1      Arménie   2019   2958000.0                     2.070
# 1          2  Afghanistan   2019  38042000.0                    17.887
# 2          3      Albanie   2019   2881000.0                    -0.792
# 3          4      Algérie   2019  43053000.0                    12.881
# 4          7       Angola   2019  31825000.0                    22.329
#
#    dispo_calories  dispo_proteines  ratio_proteines_animales
# 0          3022.0            94.29                    56.061
# 1          2273.0            57.31                    18.042
# 2          3338.0           116.02                    53.844
# 3          3493.0            90.84                    26.519
# 4          2445.0            52.09                    29.833

# %%
df = pd.merge(df_dispo_alimentaire_etendu, df_indicateurs_macro, on="Code zone")
df.head(2)
# Out:
#    Code zone         Zone  Année  population  Evolution population (%)  \
# 0          1      Arménie   2019   2958000.0                     2.070
# 1          2  Afghanistan   2019  38042000.0                    17.887
#
#    dispo_calories  dispo_proteines  ratio_proteines_animales  \
# 0          3022.0            94.29                    56.061
# 1          2273.0            57.31                    18.042
#
#    Croissance annuelle US$ par habitant  PIB Total US$ (Millions)  \
# 0                              9.529576              13672.801339
# 1                             -2.886380              17876.546427
#
#    PIB par habitant
# 0       4622.733216
# 1        469.919090

# %%
df = pd.merge(df, df_dépendance_importations, on="Code zone")

df.head(2)
# Out:
#    Code zone         Zone  Année  population  Evolution population (%)  \
# 0          1      Arménie   2019   2958000.0                     2.070
# 1          2  Afghanistan   2019  38042000.0                    17.887
#
#    dispo_calories  dispo_proteines  ratio_proteines_animales  \
# 0          3022.0            94.29                    56.061
# 1          2273.0            57.31                    18.042
#
#    Croissance annuelle US$ par habitant  PIB Total US$ (Millions)  \
# 0                              9.529576              13672.801339
# 1                             -2.886380              17876.546427
#
#    PIB par habitant  Disponibilité intérieure  Importations - Quantité  \
# 0       4622.733216                55000000.0               43000000.0
# 1        469.919090                67000000.0               44000000.0
#
#    Production  taux_dépendance_importations
# 0  12000000.0                     78.181818
# 1  28000000.0                     65.671642

# %%
df["dispo_calories"] *= 365
df["dispo_proteines"] *= 365

# %%
df.head(2)
# Out:
#    Code zone         Zone  Année  population  Evolution population (%)  \
# 0          1      Arménie   2019   2958000.0                     2.070
# 1          2  Afghanistan   2019  38042000.0                    17.887
#
#    dispo_calories  dispo_proteines  ratio_proteines_animales  \
# 0       1103030.0         34415.85                    56.061
# 1        829645.0         20918.15                    18.042
#
#    Croissance annuelle US$ par habitant  PIB Total US$ (Millions)  \
# 0                              9.529576              13672.801339
# 1                             -2.886380              17876.546427
#
#    PIB par habitant  Disponibilité intérieure  Importations - Quantité  \
# 0       4622.733216                55000000.0               43000000.0
# 1        469.919090                67000000.0               44000000.0
#
#    Production  taux_dépendance_importations
# 0  12000000.0                     78.181818
# 1  28000000.0                     65.671642

# %%
# Visualiser les pays qui n'apparaissent pas dans le dataframe étendu
df_zone_absentes = df_population[df_population["Zone"].isin(df["Zone"]) == False]
df_zone_absentes
# Out:
# Année  Code zone                       Zone  population  \
# 151          214  Chine, Taiwan Province de  23774000.0
#
# Année  Evolution population (%)
# 151                       1.503

# %%
df_dispo_alimentaire_etendu.head()
# Out:
#    Code zone         Zone  Année  population  Evolution population (%)  \
# 0          1      Arménie   2019   2958000.0                     2.070
# 1          2  Afghanistan   2019  38042000.0                    17.887
# 2          3      Albanie   2019   2881000.0                    -0.792
# 3          4      Algérie   2019  43053000.0                    12.881
# 4          7       Angola   2019  31825000.0                    22.329
#
#    dispo_calories  dispo_proteines  ratio_proteines_animales
# 0          3022.0            94.29                    56.061
# 1          2273.0            57.31                    18.042
# 2          3338.0           116.02                    53.844
# 3          3493.0            90.84                    26.519
# 4          2445.0            52.09                    29.833

# %%
df_dispo_alimen= df_dispo_alimentaire_etendu[['Evolution population (%)','dispo_calories','dispo_proteines','ratio_proteines_animales']
                                            
                                            ]

# %% [markdown]
# Quelques remarques peuvent-être apportées, comme la corrélation linéaire de la disponibilité en protéines / disponibilité calorique.
# On a également une idée de la distribution de nos 4 principales variables, avec par exemple  une distribution plutôt symétrique, c'est à dire une distribution normale pour la disponibilité calorique et la disponibilité de protéines . Voyons comment élaborer le partitionnement adéquat aux objectifs fixés.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 178 entries, 0 to 177
# Data columns (total 15 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Code zone                             178 non-null    int64
#  1   Zone                                  178 non-null    object
#  2   Année                                 178 non-null    int64
#  3   population                            178 non-null    float64
#  4   Evolution population (%)              177 non-null    float64
#  5   dispo_calories                        178 non-null    float64
#  6   dispo_proteines                       178 non-null    float64
#  7   ratio_proteines_animales              178 non-null    float64
#  8   Croissance annuelle US$ par habitant  178 non-null    float64
#  9   PIB Total US$ (Millions)              178 non-null    float64
#  10  PIB par habitant                      178 non-null    float64
#  11  Disponibilité intérieure              178 non-null    float64
#  12  Importations - Quantité               177 non-null    float64
#  13  Production                            176 non-null    float64
#  14  taux_dépendance_importations          177 non-null    float64
# dtypes: float64(12), int64(2), object(1)
# memory usage: 22.2+ KB

# %%
#Identifier la présence de doublons
print(df.duplicated().sum())
# Out:
# 0

# %%
#Trouver les valeurs manquantes
df_null=  df.loc[df.isnull().any(axis=1)]
df_null
# Out:
#      Code zone                                    Zone  Année  population  \
# 19          29                                 Burundi   2019  11531000.0
# 48          72                                Djibouti   2019    974000.0
# 96         132                                Maldives   2019    531000.0
# 165        236  Venezuela (République bolivarienne du)   2019  28516000.0
#
#      Evolution population (%)  dispo_calories  dispo_proteines  \
# 19                        NaN        666125.0         15822.75
# 48                     10.306       1020175.0         24064.45
# 96                     27.644        807380.0         29203.65
# 165                    -4.248        804460.0         18815.75
#
#      ratio_proteines_animales  Croissance annuelle US$ par habitant  \
# 19                      7.082                             -5.516413
# 48                     19.733                              6.682792
# 96                     61.430                              3.378441
# 165                    43.705                            -32.978210
#
#      PIB Total US$ (Millions)  PIB par habitant  Disponibilité intérieure  \
# 19                3002.350447        260.381563                 7000000.0
# 48                3166.329057       3252.320409                 3000000.0
# 96                5642.163793      10626.484440                12000000.0
# 165             134960.288472       4732.820093               428000000.0
#
#      Importations - Quantité   Production  taux_dépendance_importations
# 19                       0.0    7000000.0                      0.000000
# 48                 3000000.0          NaN                    100.000000
# 96                11000000.0          NaN                     91.666667
# 165                      NaN  428000000.0                           NaN

# %%
df.describe()
# Out:
#         Code zone   Année    population  Evolution population (%)  \
# count  178.000000   178.0  1.780000e+02                177.000000
# mean   127.629213  2019.0  5.103642e+07                  8.114780
# std     74.740815     0.0  1.863862e+08                  7.773391
# min      1.000000  2019.0  5.300000e+04                -12.810000
# 25%     66.250000  2019.0  2.790250e+06                  2.816000
# 50%    122.500000  2019.0  9.891000e+06                  7.197000
# 75%    188.750000  2019.0  3.191875e+07                 13.826000
# max    351.000000  2019.0  1.465634e+09                 32.138000
#
#        dispo_calories  dispo_proteines  ratio_proteines_animales  \
# count    1.780000e+02       178.000000                178.000000
# mean     1.052619e+06     29783.712921                 42.680882
# std      1.669876e+05      7662.181828                 16.098433
# min      6.230550e+05      9457.150000                  7.082000
# 25%      9.390538e+05     23844.537500                 28.918750
# 50%      1.050835e+06     29621.575000                 43.872000
# 75%      1.201854e+06     35398.612500                 56.142000
# max      1.409630e+06     52538.100000                 74.662000
#
#        Croissance annuelle US$ par habitant  PIB Total US$ (Millions)  \
# count                            178.000000              1.780000e+02
# mean                               0.196097              5.638667e+05
# std                                7.475384              2.280861e+06
# min                              -32.978210              1.948667e+02
# 25%                               -2.994627              1.242825e+04
# 50%                                0.093035              4.269907e+04
# 75%                                3.213539              2.505294e+05
# max                               28.949443              2.143323e+07
#
#        PIB par habitant  Disponibilité intérieure  Importations - Quantité  \
# count        178.000000              1.780000e+02             1.770000e+02
# mean       14067.468345              8.038764e+08             9.489266e+07
# std        19779.110886              2.760836e+09             2.242218e+08
# min          260.381563              2.000000e+06             0.000000e+00
# 25%         1863.037073              3.250000e+07             4.000000e+06
# 50%         6047.268633              1.105000e+08             1.900000e+07
# 75%        16818.669192              3.330000e+08             8.600000e+07
# max       115480.867570              2.138600e+10             1.814000e+09
#
#          Production  taux_dépendance_importations
# count  1.760000e+02                    177.000000
# mean   8.620227e+08                     44.214572
# std    3.026034e+09                     50.192418
# min    0.000000e+00                      0.000000
# 25%    1.175000e+07                      4.152047
# 50%    7.600000e+07                     26.865672
# 75%    3.512500e+08                     79.411765
# max    2.285800e+10                    404.026846

# %%
df.style.background_gradient(cmap='BrBG')
# Out:
# <style  type="text/css" >
# #T_9e66d_row0_col0,#T_9e66d_row0_col2,#T_9e66d_row0_col3,#T_9e66d_row0_col9,#T_9e66d_row0_col11,#T_9e66d_row0_col13,#T_9e66d_row1_col0,#T_9e66d_row1_col2,#T_9e66d_row1_col9,#T_9e66d_row1_col10,#T_9e66d_row1_col11,#T_9e66d_row1_col13,#T_9e66d_row2_col2,#T_9e66d_row2_col3,#T_9e66d_row2_col9,#T_9e66d_row2_col11,#T_9e66d_row2_col13,#T_9e66d_row3_col2,#T_9e66d_row3_col12,#T_9e66d_row3_col14,#T_9e66d_row4_col2,#T_9e66d_row4_col13,#T_9e66d_row5_col2,#T_9e66d_row5_col3,#T_9e66d_row5_col9,#T_9e66d_row5_col11,#T_9e66d_row5_col12,#T_9e66d_row5_col13,#T_9e66d_row6_col2,#T_9e66d_row6_col12,#T_9e66d_row6_col14,#T_9e66d_row7_col2,#T_9e66d_row7_col14,#T_9e66d_row8_col2,#T_9e66d_row9_col2,#T_9e66d_row9_col3,#T_9e66d_row9_col9,#T_9e66d_row9_col11,#T_9e66d_row9_col13,#T_9e66d_row10_col2,#T_9e66d_row10_col3,#T_9e66d_row10_col9,#T_9e66d_row10_col11,#T_9e66d_row10_col12,#T_9e66d_row10_col13,#T_9e66d_row11_col2,#T_9e66d_row11_col12,#T_9e66d_row11_col14,#T_9e66d_row12_col2,#T_9e66d_row12_col9,#T_9e66d_row12_col12,#T_9e66d_row12_col14,#T_9e66d_row13_col2,#T_9e66d_row13_col3,#T_9e66d_row13_col9,#T_9e66d_row13_col11,#T_9e66d_row13_col12,#T_9e66d_row13_col13,#T_9e66d_row14_col2,#T_9e66d_row14_col12,#T_9e66d_row14_col14,#T_9e66d_row15_col2,#T_9e66d_row15_col3,#T_9e66d_row15_col9,#T_9e66d_row15_col11,#T_9e66d_row15_col12,#T_9e66d_row15_col13,#T_9e66d_row15_col14,#T_9e66d_row16_col2,#T_9e66d_row16_col3,#T_9e66d_row16_col9,#T_9e66d_row16_col11,#T_9e66d_row16_col12,#T_9e66d_row16_col13,#T_9e66d_row17_col2,#T_9e66d_row17_col9,#T_9e66d_row18_col2,#T_9e66d_row18_col9,#T_9e66d_row18_col12,#T_9e66d_row18_col14,#T_9e66d_row19_col2,#T_9e66d_row19_col7,#T_9e66d_row19_col9,#T_9e66d_row19_col10,#T_9e66d_row19_col11,#T_9e66d_row19_col12,#T_9e66d_row19_col13,#T_9e66d_row19_col14,#T_9e66d_row20_col2,#T_9e66d_row20_col9,#T_9e66d_row20_col11,#T_9e66d_row20_col12,#T_9e66d_row20_col13,#T_9e66d_row21_col2,#T_9e66d_row22_col2,#T_9e66d_row22_col3,#T_9e66d_row22_col9,#T_9e66d_row22_col11,#T_9e66d_row22_col13,#T_9e66d_row23_col2,#T_9e66d_row23_col3,#T_9e66d_row23_col9,#T_9e66d_row23_col10,#T_9e66d_row23_col11,#T_9e66d_row23_col12,#T_9e66d_row23_col13,#T_9e66d_row24_col2,#T_9e66d_row24_col12,#T_9e66d_row24_col14,#T_9e66d_row25_col2,#T_9e66d_row25_col9,#T_9e66d_row25_col10,#T_9e66d_row25_col11,#T_9e66d_row25_col12,#T_9e66d_row25_col13,#T_9e66d_row26_col2,#T_9e66d_row27_col2,#T_9e66d_row28_col2,#T_9e66d_row29_col2,#T_9e66d_row29_col3,#T_9e66d_row29_col9,#T_9e66d_row29_col11,#T_9e66d_row29_col12,#T_9e66d_row29_col13,#T_9e66d_row29_col14,#T_9e66d_row30_col2,#T_9e66d_row30_col3,#T_9e66d_row30_col9,#T_9e66d_row30_col13,#T_9e66d_row31_col2,#T_9e66d_row31_col3,#T_9e66d_row31_col9,#T_9e66d_row32_col2,#T_9e66d_row32_col13,#T_9e66d_row33_col2,#T_9e66d_row33_col3,#T_9e66d_row33_col9,#T_9e66d_row33_col11,#T_9e66d_row33_col13,#T_9e66d_row34_col2,#T_9e66d_row34_col9,#T_9e66d_row35_col2,#T_9e66d_row35_col9,#T_9e66d_row35_col13,#T_9e66d_row36_col2,#T_9e66d_row36_col3,#T_9e66d_row37_col2,#T_9e66d_row37_col3,#T_9e66d_row37_col9,#T_9e66d_row37_col11,#T_9e66d_row37_col12,#T_9e66d_row37_col13,#T_9e66d_row38_col2,#T_9e66d_row39_col2,#T_9e66d_row39_col9,#T_9e66d_row40_col2,#T_9e66d_row40_col12,#T_9e66d_row40_col14,#T_9e66d_row41_col2,#T_9e66d_row42_col2,#T_9e66d_row42_col9,#T_9e66d_row43_col2,#T_9e66d_row43_col3,#T_9e66d_row43_col9,#T_9e66d_row43_col11,#T_9e66d_row43_col13,#T_9e66d_row44_col2,#T_9e66d_row44_col3,#T_9e66d_row44_col9,#T_9e66d_row44_col11,#T_9e66d_row44_col12,#T_9e66d_row44_col13,#T_9e66d_row45_col2,#T_9e66d_row45_col3,#T_9e66d_row46_col2,#T_9e66d_row47_col2,#T_9e66d_row47_col3,#T_9e66d_row47_col9,#T_9e66d_row47_col11,#T_9e66d_row47_col13,#T_9e66d_row48_col2,#T_9e66d_row48_col3,#T_9e66d_row48_col9,#T_9e66d_row48_col11,#T_9e66d_row48_col12,#T_9e66d_row49_col2,#T_9e66d_row49_col3,#T_9e66d_row49_col9,#T_9e66d_row49_col11,#T_9e66d_row49_col13,#T_9e66d_row50_col2,#T_9e66d_row50_col3,#T_9e66d_row50_col9,#T_9e66d_row50_col11,#T_9e66d_row50_col13,#T_9e66d_row51_col2,#T_9e66d_row51_col3,#T_9e66d_row5 ...

# %% [markdown]
# # Classification hiérarchique

# %% [markdown]
# ## Corrélations

# %% [markdown]
# Avant de réaliser l'ACP, on peut vérifier la corrélation des variables avec une matrice des corrélations.
#
# Fortes corrélations entre :
#
# la dispo. en protéines et la dispo. en calories.\
# la dispo. en protéines et le ratio de protéines animales.\
# la Disponibilité intérieure et le PIB.
#
# Nous sommes intéressés par les pays les plus susceptibles de consommer du poulet, donc ceux ayant un fort ratio de protéines animales. Les corrélations montrent que ces pays sont susceptibles d'avoir un fort PIB, et de grandes disponibilités en protéines et calories.des disponibilités en protéines et calories.

# %%
# Calculate pairwise-correlation
matrix = df.corr()

# Triangle de corrélations
mask = np.triu(np.ones_like(matrix, dtype=np.bool))
plt.figure(figsize=(26, 10))
sns.heatmap(matrix, mask=mask, annot=True, cmap='BrBG')
plt.show()
# Out:
# <ipython-input-38-08ce70fc63ab>:5: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(matrix, dtype=np.bool))

# %%
conda install -c conda-forge geopandas
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import geopandas as gpd
import geoplot
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-3c05bbec7d98> in <module>
# ----> 1 import geopandas as gpd
#       2 import geoplot
#
# ~/opt/anaconda3/lib/python3.8/site-packages/geopandas/__init__.py in <module>
# ----> 1 from geopandas.geoseries import GeoSeries  # noqa
#       2 from geopandas.geodataframe import GeoDataFrame  # noqa
#       3 from geopandas.array import _points_from_xy as points_from_xy  # noqa
#       4
#       5 from geopandas.io.file import read_file  # noqa
#
# ~/opt/anaconda3/lib/python3.8/site-packages/geopandas/geoseries.py in <module>
#      10
#      11 import pyproj
# ---> 12 from shapely.geometry.base import BaseGeometry
#      13 from shapely.ops import transform
#      14
#
# ~/opt/anaconda3/lib/python3.8/site-packages/shapely/geometry/__init__.py in <module>
#       2 """
#       3
# ----> 4 from .base import CAP_STYLE, JOIN_STYLE
#       5 from .geo import box, shape, asShape, mapping
#       6 from .point import Point, asPoint
#
# ~/opt/anaconda3/lib/python3.8/site-packages/shapely/geometry/base.py in <module>
#      15
#      16 from shapely.affinity import affine_transform
# ---> 17 from shapely.coords import CoordinateSequence
#      18 from shapely.errors import WKBReadingError, WKTReadingError
#      19 from shapely.ftools import wraps
#
# ~/opt/anaconda3/lib/python3.8/site-packages/shapely/coords.py in <module>
#       6 from ctypes import byref, c_double, c_uint
#       7
# ----> 8 from shapely.geos import lgeos
#       9 from shapely.topology import Validating
#      10
#
# ~/opt/anaconda3/lib/python3.8/site-packages/shapely/geos.py in <module>
#     111         _lgeos = load_dll('geos_c', fallbacks=alt_paths)
#     112
# --> 113     free = load_dll('c').free
#     114     free.argtypes = [c_void_p]
#     115     free.restype = None
#
# ~/opt/anaconda3/lib/python3.8/site-packages/shapely/geos.py in load_dll(libname, fallbacks, mode)
#      52     else:
#      53         # No shared library was loaded. Raise OSError.
# ---> 54         raise OSError(
#      55             "Could not find lib {0} or load any of its variants {1}.".format(
#      56                 libname, fallbacks or []))
#
# OSError: Could not find lib c or load any of its variants [].
